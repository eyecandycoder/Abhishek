# %% [markdown]
# <a href="https://colab.research.google.com/github/eyecandycoder/Abhishek/blob/main/Polynomial%20Linear%20Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Position_Salaries.csv')

# %%
X= dataset.iloc[: , 1: -1].values
y = dataset.iloc[: , -1].values

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X,y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
Poly_regressor = PolynomialFeatures(degree =2)
X_poly = Poly_regressor.fit_transform(X)
regressor2  = LinearRegression()
regressor2.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,y,color = 'red')
plt.plot(X,regressor.predict(X), color = 'blue')
plt.title('Truth or BLuff (Linear regression Model)')
plt.xlabel('Position level')
plt.ylabel('Salaries')
plt.show()

# %%
plt.scatter(X,y,color = 'red')
plt.plot(X,regressor2.predict(X_poly), color = 'blue')
plt.title('Truth or BLuff (Polynomial Linear regression Model)')
plt.xlabel('Position level')
plt.ylabel('Salaries')
plt.show()

# %% [markdown]
# Linear regressor_test case

# %%
regressor.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# Poly_regressor Test case

# %%
regressor2.predict(Poly_regressor.fit_transform([[6.5]]))
# Out:
# array([189498.10606061])
